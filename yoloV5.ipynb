# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pwd
# Out:
# '/content/drive/My Drive/yolo5_Model'

# %%
# %cd /content/drive/MyDrive/yolo5_Model/
# Out:
# /content/drive/MyDrive/yolo5_Model

# %%
import torch

# %%
from IPython.display import Image

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# %cd yolov5
# Out:
# /content/drive/MyDrive/yolo5_Model/yolov5

# %%
# !pip install -r requirements.txt

# %%
# !python train.py --img 416 --batch 16 --epochs 200 --data dataset.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=dataset.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=200, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.2-239-gf33718f Python-3.7.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# Validate YOLOv5s on COCO val
# !python val.py --weights /content/drive/MyDrive/yolo5_Model/yolov5/runs/train/exp16/weights/best.pt --data /content/drive/MyDrive/yolo5_Model/yolov5/data/dataset.yaml --img 416 --half
# Out:
# val: data=/content/drive/MyDrive/yolo5_Model/yolov5/data/dataset.yaml, weights=['/content/drive/MyDrive/yolo5_Model/yolov5/runs/train/exp16/weights/best.pt'], batch_size=32, imgsz=416, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=True, dnn=False
# YOLOv5 🚀 v6.2-239-gf33718f Python-3.7.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# val: Scanning '/content/drive/MyDrive/yolo5_Model/Fruits_dataset_yoloV5/labels/val.cache' images and labels... 60 found, 0 missing, 0 empty, 4 corrupt: 100% 60/60 [00:00<?, ?it/s]
# ...

# %%
pwd
# Out:
# '/content/drive/MyDrive/yolo5_Model/yolov5'

# %%
# !python detect.py --weights /content/drive/MyDrive/yolo5_Model/yolov5/runs/train/exp16/weights/best.pt --img 416 --conf 0.25 --source apples-bananas.jpg
# display.Image(filename='runs/detect/exp/zidane.jpg', width=600)
# Out:
# detect: weights=['/content/drive/MyDrive/yolo5_Model/yolov5/runs/train/exp16/weights/best.pt'], source=apples-bananas.jpg, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-239-gf33718f Python-3.7.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/drive/MyDrive/yolo5_Model/yolov5/apples-bananas.jpg: 320x416 3 Apples, 1 Banana, 11.3ms
# Speed: 0.4ms pre-process, 11.3ms inference, 1.3ms NMS per image at shape (1, 3, 416, 416)
# Results saved to runs/detect/exp16

# %%
from PIL import Image

# %%
# Image.open('runs/detect/exp7/apples-bananas.jpg')
import matplotlib.pyplot as plt 
fig = plt.figure(figsize=(12,12))
plt.axis(False)
processed_image = plt.imread("/content/drive/MyDrive/yolo5_Model/yolov5/runs/detect/exp16/apples-bananas.jpg")
plt.imshow(processed_image)
plt.show()
